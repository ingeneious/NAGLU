# %%
import numpy as np
from datascience import *
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
answer_key_with_rel_act = Table.read_table('#zn6m1 NAGLU ANSWER KEY.tsv')
answer_key_with_rel_act
# Out:
# AA_substitution | relative_activity | standard_deviation
# A16V            | 0.42              | 0.005
# V117A           | nan               | nan
# P118S           | 0.5               | 0.071
# Y131S           | 0.04              | 0.022
# V135G           | 0.21              | 0.045
# T137M           | 0.25              | 0.061
# S141T           | 0.34              | 0.026
# R152Q           | 0.35              | 0.071
# I154T           | 0.04              | 0.031
# A158S           | 0.1               | 0.025
# ... (155 rows omitted)

# %%
answer_key_with_rel_act_filtered = answer_key_with_rel_act.sort("AA_substitution")
answer_key_with_rel_act_filtered.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>AA_substitution</th> <th>relative_activity</th> <th>standard_deviation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A158S          </td> <td>0.1              </td> <td>0.025             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A16V           </td> <td>0.42             </td> <td>0.005             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A181D          </td> <td>0.54             </td> <td>0.031             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A244T          </td> <td>0.2              </td> <td>0.027             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A329T          </td> <td>0.87             </td> <td>0.15              </td>
#         </tr>
#     </tbody>
#         <tr>
# ...

# %%
answer_key_with_rel_act_filtered = answer_key_with_rel_act_filtered.with_column("Effect (< 10%)", answer_key_with_rel_act_filtered.column(1) < 0.10)
answer_key_with_rel_act_filtered.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in less
#   if __name__ == '__main__':
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>AA_substitution</th> <th>relative_activity</th> <th>standard_deviation</th> <th>Effect (< 10%)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A158S          </td> <td>0.1              </td> <td>0.025             </td> <td>False         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A16V           </td> <td>0.42             </td> <td>0.005             </td> <td>False         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>A181D          </td> <td>0.54             </td> <td>0.031             </td> <td>False         </td>
#         </tr>
#     </tbody>
#         <tr>
# ...

# %%
answer_key_with_rel_act_filtered.to_tsv()
